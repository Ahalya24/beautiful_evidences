# %%
import pandas as pd
import plotly.offline as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/1389428/Desktop/Analytics/polnet2018/Data files/graph_dept.csv')

# %%
G = nx.Graph()

# %%
node_list = [48,88,49]
G.add_nodes_from(node_list)

# %%
edge_list = [(88,90,2000), (48,90,100) , (88,42,15) , (88,9,25) , (88,19,15) , (49,90,27)]
G.add_weighted_edges_from(edge_list)

# %%
nx.draw_networkx_nodes(G, pos,nodelist=[48,88,49],node_color='b',node_size=500,alpha=0.8)
nx.draw_networkx_nodes(G, pos,nodelist=[90,42,9,19],node_color='r',node_size=500,alpha=0.8)
nx.draw_networkx_edges(G, pos, width=1.0, alpha=0.5, with_labes = True)

# %%
nx.draw(G, with_labels=True, font_weight='bold')

# %%
edges = G.edges()

# %%
from networkx.algorithms import bipartite
X, Y = bipartite.sets(G)

# %%
pos = dict()
pos.update( (n, (1, i)) for i, n in enumerate(X) ) # put nodes from X at x=1
pos.update( (n, (2, i)) for i, n in enumerate(Y) ) # put nodes from Y at x=2
nx.draw_networkx(G, pos=pos, edges=edges)
plt.show()

# %%
from networkx.algorithms import bipartite
B = nx.path_graph(4)

# %%
G1 = bipartite.weighted_projected_graph(B, node_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-d0398e63121c> in <module>()
# ----> 1 G1 = bipartite.weighted_projected_graph(B, node_list)
#
# <decorator-gen-401> in weighted_projected_graph(B, nodes, ratio)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\utils\decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      71             raise nx.NetworkXNotImplemented(msg)
#      72         else:
# ---> 73             return not_implement_for_func(*args, **kwargs)
#      74     return _not_implemented_for
#      75
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\networkx\algorithms\bipartite\projection.py in weighted_projected_graph(B, nodes, ratio)
#     197         G = nx.Graph()
#     198     G.graph.update(B.graph)
# --> 199     G.add_nodes_from((n, B.nodes[n]) for n in nodes)
# ...

# %%
node_list
# Out:
# [48, 88, 49]

# %%
 [(i.upper(), len(i)) for i in 'kiwi' ]
